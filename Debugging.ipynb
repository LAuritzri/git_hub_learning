# %%
x = 1000
y = 1000
result = x * y
result
# Out:
# 1000000

# %%
result_1 = result * y + x
result_1
# Out:
# 1000001000

# %%
result_2 = result_1 - result + y - x
result_2
# Out:
# 999001000

# %%
result_3 = result_2 + t
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 result_3 = result_2 + t
#
# NameError: name 't' is not defined
